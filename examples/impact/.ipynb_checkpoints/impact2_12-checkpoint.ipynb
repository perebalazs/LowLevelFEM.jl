# %%
using LowLevelFEM
import LowLevelFEM as FEM
gmsh.initialize()

# %%
l = 100
n = 100
# Out:
# 100

# %%
gmsh.parser.setNumber("length", [l])
gmsh.parser.setNumber("elements", [n])

# %%
gmsh.merge("rod.geo")
# Out:
# Info    : Reading 'rod.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000352917s, CPU 0.000343s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 0.000642093s, CPU 0.000641s)
# Info    : 202 nodes 306 elements
# Info    : Done reading 'rod.geo'

# %%
mat = FEM.material("body", E=2e5, ν=0)
problem = FEM.Problem([mat], type=:PlaneStress, bandwidth=:RCMK)
# Out:
# Info    : RCMK renumbering...
# Info    : Done RCMK renumbering (bandwidth is now 3)
# LowLevelFEM.Problem("rod", :PlaneStress, 2, 2, LowLevelFEM.Material[LowLevelFEM.Material("body", 200000.0, 0.0, 7.85e-9, 45.0, 4.2e8, 1.2e-5)], 1.0, 202)

# %%
supp1 = FEM.displacementConstraint("left", ux=0)
supp2 = FEM.displacementConstraint("bottom", uy=0)
supp3 = FEM.displacementConstraint("right", ux=0)
# Out:
# ("right", 0, 0 + 1im, 0 + 1im)

# %%
#load = FEM.load("right", fx=1)
#u = FEM.solveDisplacement(problem, [load], [supp1, supp2])
#FEM.showDoFResults(problem, u, :ux, visible=true)

# %%
K = FEM.stiffnessMatrix(problem)
# Out:
# 404×404 SparseArrays.SparseMatrixCSC{Float64, Int64} with 4757 stored entries:
# ⎡⠻⣦⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎤
# ⎢⠀⠙⢻⣶⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠉⢻⣶⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠉⢻⣶⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠈⢿⣷⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣷⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠿⣧⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠿⣧⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠿⣧⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠻⣦⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠻⣦⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⢻⣶⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⢻⣶⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⢻⣶⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣷⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣷⡀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠿⣧⣀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠿⣧⣀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠿⣧⣄⠀⎥
# ⎣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠻⣦⎦

# %%
M = FEM.massMatrix(problem)
# Out:
# 404×404 SparseArrays.SparseMatrixCSC{Float64, Int64} with 404 stored entries:
# ⎡⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎤
# ⎢⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⎥
# ⎣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⎦

# %%
Tmin = FEM.smallestPeriodTime(K, M)
# Out:
# 6.224001709051475e-7

# %%
u0 = FEM.initialDisplacement(problem, "body", ux=0, uy=0);

# %%
v0 = FEM.initialVelocity(problem, "body", vx=1000)
FEM.initialVelocity!(problem, "right", v0, vx=0)

# %%
ωₘₐₓ = 2π / Tmin
C = FEM.dampingMatrix(K, M, ωₘₐₓ, ξ=0);

# %%
dummyLoad = FEM.load("right", fx=0)
f = FEM.loadVector(problem, [dummyLoad]);

# %%
FEM.applyBoundaryConditions!(problem, K, M, C, f, [supp2, supp3]);

# %%
Δt = Tmin / π
c = √(problem.material[1].E / problem.material[1].ρ);
T = 2l / c;

# %%
u, v, t = FEM.CDM(K, M, C, f, u0, v0, T, Δt * 0.5);

# %%
S = FEM.solveStress(problem, u);

# %%
S = FEM.elementsToNodes(problem, S);

# %%
sx = FEM.showDoFResults(problem, S, :sx, t=t);
# Out:
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 19700101
# Build host    : amdci7.julia.csail.mit.edu
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack LinuxJoystick MathEx[contrib] Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.8
# OCC version   : 7.7.2
# Packaged by   : root
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
# XOpenIM() failed
# XRequest.18: BadValue 0x0

# %%
psx = FEM.plotOnPath(problem, "path", sx, points=n + 1, visible=true)
psx2, xy = FEM.plotOnPath(problem, "path", sx, points=(n + 1) * 10, step=length(t) ÷ 4, plot=true);

# %%
using Plots
#plotlyjs()
plot(xy)

# %%
fdof = length(FEM.freeDoFs(problem, [supp1, supp2]))
# Out:
# 301

# %%
Φ = FEM.solveModalAnalysis(problem, constraints=[supp1, supp2], n=fdof)
f = Φ.f
# Out:
# ┌ Warning: Adjusting nev from 301 to 299
# └ @ Arpack /home/perebal/.julia/packages/Arpack/FCvNd/src/Arpack.jl:92
# 299-element Vector{Float64}:
#   12618.731896060448
#   37853.08220489133
#   63078.09283209883
#   88287.53988375803
#  113475.20330602583
#  138634.8684198439
#  163760.32745431745
#  188845.38107839003
#  213883.83993043526
#  238869.52614539102
#       ⋮
#       1.5848794767230633e6
#       1.5888274858703513e6
#       1.5923834756096376e6
#       1.595546568553668e6
#       1.598315984256581e6
#       1.6006910394064954e6
#       1.6026711479940834e6
#       1.6042558214571988e6
#       1.605444668801359e6

# %%
q = Φ.ϕ' * u
# Out:
# 299×401 Matrix{Float64}:
#  0.0   0.0012451     0.00248528    0.00371684   …   0.00132285    9.74854e-5
#  0.0   0.000428108   0.000861139   0.00130278       0.000350992  -9.69718e-5
#  0.0   0.000241012   0.00047711    0.000704622      0.000316948   9.59799e-5
#  0.0   0.00018896    0.000382818   0.000585227      0.000114937  -9.44134e-5
#  0.0  -0.000129354  -0.000253829  -0.000369802     -0.000200938  -9.23762e-5
#  0.0  -0.000123662  -0.00025218   -0.000389139  …  -5.54026e-5    8.96711e-5
#  0.0  -8.63451e-5   -0.000167864  -0.000241014     -0.000150742  -8.64646e-5
#  0.0  -9.3135e-5    -0.000191062  -0.000297275     -3.36874e-5    8.24511e-5
#  0.0  -6.35269e-5   -0.0001223    -0.000172882     -0.000117426  -7.78536e-5
#  0.0  -7.54176e-5   -0.000155546  -0.000243758     -2.83971e-5    7.22512e-5
#  ⋮                                              ⋱                 ⋮
#  0.0   1.14972e-5    1.83319e-5    1.91461e-5   …   7.75109e-6    4.05915e-6
#  0.0   8.37477e-6    1.20391e-5    9.65673e-6       4.24987e-6    2.56339e-6
#  0.0   1.11806e-5    1.76075e-5    1.79644e-5       4.69018e-6    1.62716e-6
#  0.0   8.69003e-6    1.25879e-5    1.03954e-5       2.39907e-6    2.74429e-6
#  0.0  -1.08665e-5   -1.69072e-5   -1.68396e-5      -4.46309e-6   -3.40804e-6
#  0.0   9.00297e-6    1.3151e-5     1.11759e-5   …   3.79846e-6    4.15719e-6
#  0.0  -1.05545e-5   -1.62299e-5   -1.57697e-5      -5.41139e-6   -3.94943e-6
#  0.0  -9.3142e-6    -1.37298e-5   -1.20001e-5      -4.65285e-6   -3.87065e-6
#  0.0   1.02439e-5    1.55747e-5    1.47527e-5       5.30894e-6    3.47573e-6

# %%
plot(Φ.f, abs.(q[:, size(q, 2)÷4]))

# %%
gmsh.fltk.run()

# %%
gmsh.finalize()

# %%
q_old = q;

# %%
using LowLevelFEM
import LowLevelFEM as FEM
gmsh.initialize()

# %%
l = 100
n = 200
# Out:
# 200

# %%
gmsh.parser.setNumber("length", [l])
gmsh.parser.setNumber("elements", [n])

# %%
gmsh.merge("rod.geo")
# Out:
# Info    : Reading 'rod.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000562308s, CPU 0.000553s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00179013s, CPU 0.001788s)
# Info    : 402 nodes 606 elements
# Info    : Done reading 'rod.geo'

# %%
mat = FEM.material("body", E=2e5, ν=0)
problem = FEM.Problem([mat], type=:PlaneStress, bandwidth=:RCMK)
# Out:
# Info    : RCMK renumbering...
# Info    : Done RCMK renumbering (bandwidth is now 3)
# LowLevelFEM.Problem("rod", :PlaneStress, 2, 2, LowLevelFEM.Material[LowLevelFEM.Material("body", 200000.0, 0.0, 7.85e-9, 45.0, 4.2e8, 1.2e-5)], 1.0, 402)

# %%
supp1 = FEM.displacementConstraint("left", ux=0)
supp2 = FEM.displacementConstraint("bottom", uy=0)
supp3 = FEM.displacementConstraint("right", ux=0)
# Out:
# ("right", 0, 0 + 1im, 0 + 1im)

# %%
#load = FEM.load("right", fx=1)
#u = FEM.solveDisplacement(problem, [load], [supp1, supp2])
#FEM.showDoFResults(problem, u, :ux, visible=true)

# %%
K = FEM.stiffnessMatrix(problem)
# Out:
# 804×804 SparseArrays.SparseMatrixCSC{Float64, Int64} with 9440 stored entries:
# ⎡⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎤
# ⎢⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⎥
# ⎣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⎦

# %%
M = FEM.massMatrix(problem)
# Out:
# 804×804 SparseArrays.SparseMatrixCSC{Float64, Int64} with 804 stored entries:
# ⎡⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎤
# ⎢⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⎥
# ⎣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⎦

# %%
Tmin = FEM.smallestPeriodTime(K, M)
# Out:
# 3.112000854525752e-7

# %%
u0 = FEM.initialDisplacement(problem, "body", ux=0, uy=0);

# %%
v0 = FEM.initialVelocity(problem, "body", vx=1000)
FEM.initialVelocity!(problem, "right", v0, vx=0)

# %%
ωₘₐₓ = 2π / Tmin
C = FEM.dampingMatrix(K, M, ωₘₐₓ, ξ=0);

# %%
dummyLoad = FEM.load("right", fx=0)
f = FEM.loadVector(problem, [dummyLoad]);

# %%
FEM.applyBoundaryConditions!(problem, K, M, C, f, [supp2, supp3]);

# %%
Δt = Tmin / π
c = √(problem.material[1].E / problem.material[1].ρ);
T = 2l / c;

# %%
u, v, t = FEM.CDM(K, M, C, f, u0, v0, T, Δt * 0.5);

# %%
S = FEM.solveStress(problem, u);

# %%
S = FEM.elementsToNodes(problem, S);

# %%
sx = FEM.showDoFResults(problem, S, :sx, t=t);
# Out:
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 19700101
# Build host    : amdci7.julia.csail.mit.edu
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack LinuxJoystick MathEx[contrib] Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.8
# OCC version   : 7.7.2
# Packaged by   : root
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %%
psx = FEM.plotOnPath(problem, "path", sx, points=n + 1, visible=true)
psx2, xy = FEM.plotOnPath(problem, "path", sx, points=(n + 1) * 10, step=length(t) ÷ 4, plot=true);

# %%
using Plots
#plotlyjs()
plot(xy)

# %%
fdof = length(FEM.freeDoFs(problem, [supp1, supp2]))
# Out:
# 601

# %%
Φ = FEM.solveModalAnalysis(problem, constraints=[supp1, supp2], n=fdof)
f = Φ.f
# Out:
# ┌ Warning: Adjusting nev from 601 to 599
# └ @ Arpack /home/perebal/.julia/packages/Arpack/FCvNd/src/Arpack.jl:92
# 599-element Vector{Float64}:
#   12618.829195051327
#   37855.70919628269
#   63090.254079064056
#   88320.9072577935
#  113546.11238693536
#  138764.31345701485
#  163973.95489060212
#  189173.4816382664
#  214361.33927449593
#  239535.97409358676
#       ⋮
#       3.2024462270888826e6
#       3.2044263509444483e6
#       3.2062088106885026e6
#       3.207793496370515e6
#       3.2091803102396154e6
#       3.2103691667505945e6
#       3.2113599925691695e6
#       3.212152726576567e6
#       3.2127473198731807e6

# %%
q = Φ.ϕ' * u
# Out:
# 599×800 Matrix{Float64}:
#  0.0   0.000886117   0.00177049    0.0026518    …   0.001807      0.000931809
#  0.0  -0.000300018  -0.000601782  -0.000906602     -0.000565418  -0.000254456
#  0.0  -0.000174407  -0.000347068  -0.000516675     -0.000383124  -0.00021971
#  0.0  -0.000130549  -0.000262843  -0.000398186     -0.000227244  -8.56399e-5
#  0.0   9.53114e-5    0.00018888    0.000279404      0.000223854   0.000139698
#  0.0  -8.43173e-5   -0.000170375  -0.000259473  …  -0.000136176  -4.05987e-5
#  0.0   6.48789e-5    0.00012802    0.000188127      0.000161262   0.000107797
#  0.0   6.27325e-5    0.0001272     0.000194694      9.50698e-5    2.07736e-5
#  0.0  -4.8759e-5    -9.57868e-5   -0.000139797     -0.000126605  -8.96189e-5
#  0.0  -5.02284e-5   -0.000102184  -0.000157148     -7.28431e-5   -1.06438e-5
#  ⋮                                              ⋱
#  0.0   3.78226e-6    5.84147e-6    5.72926e-6   …   2.79442e-6    1.98391e-6
#  0.0  -3.23236e-6   -4.73738e-6   -4.06878e-6      -1.55754e-6   -1.29168e-6
#  0.0  -3.72708e-6   -5.72295e-6   -5.54322e-6      -2.46492e-6   -1.62501e-6
#  0.0  -3.28749e-6   -4.84032e-6   -4.21582e-6      -1.42234e-6   -1.1587e-6
#  0.0   3.67201e-6    5.60636e-6    5.36185e-6       2.14441e-6    1.51834e-6
#  0.0  -3.34251e-6   -4.94477e-6   -4.36687e-6   …  -1.4108e-6    -1.24654e-6
#  0.0  -3.61703e-6   -5.49167e-6   -5.18505e-6      -1.97489e-6   -1.55007e-6
#  0.0   3.39745e-6    5.05079e-6    4.522e-6         1.52229e-6    1.39056e-6
#  0.0  -3.56211e-6   -5.37882e-6   -5.01275e-6      -1.88194e-6   -1.57975e-6

# %%
gmsh.fltk.run()
# Out:
# XRequest.18: BadValue 0x0

# %%
plot(Φ.f, abs.(q[:, size(q, 2)÷4]))

# %%
nf = length(Φ.f)
plot(Φ.f[1:nf÷2], abs.(q[1:nf÷2, size(q, 2)÷4]))

# %%
u = Φ.ϕ[:, 1:nf÷2] * q[1:nf÷2, size(q, 2)÷4]
# Out:
# 804-element Vector{Float64}:
#   8.945946464983107e-5
#   2.3818671323161523e-15
#   8.945946464922307e-5
#   0.0
#   0.00010251315616661837
#   1.2485103346944746e-15
#   0.00010251315616552002
#   0.0
#   0.00015261987673924546
#  -6.985234154789592e-16
#   ⋮
#   0.0
#   0.006285052685028927
#  -1.383169546339736e-16
#   0.006285052685028431
#   0.0
#   0.0
#   6.803748283056694e-16
#   0.0
#   0.0

# %%
S = FEM.solveStress(problem, u);

# %%
S = FEM.elementsToNodes(problem, S);

# %%
sx = FEM.showDoFResults(problem, S, :sx);
# Out:
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 19700101
# Build host    : amdci7.julia.csail.mit.edu
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack LinuxJoystick MathEx[contrib] Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.8
# OCC version   : 7.7.2
# Packaged by   : root
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %%
psx = FEM.plotOnPath(problem, "path", sx, points=n + 1, visible=true)
psx2, xy = FEM.plotOnPath(problem, "path", sx, points=(n + 1) * 10, step=length(t) ÷ 4, plot=true);
# Out:
# ┌ Warning: plotOnPath: step is greater than max. number of steps (max. number is chosen)  200 <==> 1!
# └ @ LowLevelFEM /home/perebal/Dokumentumok/GitHub/LowLevelFEM.jl/src/LowLevelFEM.jl:5465

# %%
using Plots
#plotlyjs()
plot(xy)

# %%
q_old2 = q
# Out:
# 599×800 Matrix{Float64}:
#  0.0   0.000886117   0.00177049    0.0026518    …   0.001807      0.000931809
#  0.0  -0.000300018  -0.000601782  -0.000906602     -0.000565418  -0.000254456
#  0.0  -0.000174407  -0.000347068  -0.000516675     -0.000383124  -0.00021971
#  0.0  -0.000130549  -0.000262843  -0.000398186     -0.000227244  -8.56399e-5
#  0.0   9.53114e-5    0.00018888    0.000279404      0.000223854   0.000139698
#  0.0  -8.43173e-5   -0.000170375  -0.000259473  …  -0.000136176  -4.05987e-5
#  0.0   6.48789e-5    0.00012802    0.000188127      0.000161262   0.000107797
#  0.0   6.27325e-5    0.0001272     0.000194694      9.50698e-5    2.07736e-5
#  0.0  -4.8759e-5    -9.57868e-5   -0.000139797     -0.000126605  -8.96189e-5
#  0.0  -5.02284e-5   -0.000102184  -0.000157148     -7.28431e-5   -1.06438e-5
#  ⋮                                              ⋱
#  0.0   3.78226e-6    5.84147e-6    5.72926e-6   …   2.79442e-6    1.98391e-6
#  0.0  -3.23236e-6   -4.73738e-6   -4.06878e-6      -1.55754e-6   -1.29168e-6
#  0.0  -3.72708e-6   -5.72295e-6   -5.54322e-6      -2.46492e-6   -1.62501e-6
#  0.0  -3.28749e-6   -4.84032e-6   -4.21582e-6      -1.42234e-6   -1.1587e-6
#  0.0   3.67201e-6    5.60636e-6    5.36185e-6       2.14441e-6    1.51834e-6
#  0.0  -3.34251e-6   -4.94477e-6   -4.36687e-6   …  -1.4108e-6    -1.24654e-6
#  0.0  -3.61703e-6   -5.49167e-6   -5.18505e-6      -1.97489e-6   -1.55007e-6
#  0.0   3.39745e-6    5.05079e-6    4.522e-6         1.52229e-6    1.39056e-6
#  0.0  -3.56211e-6   -5.37882e-6   -5.01275e-6      -1.88194e-6   -1.57975e-6

# %%
gmsh.finalize()

# %%
#using LowLevelFEM
#import LowLevelFEM as FEM
gmsh.initialize()

# %%
l = 100
n = 100

# %%
gmsh.parser.setNumber("length", [l])
gmsh.parser.setNumber("elements", [n])

# %%
gmsh.merge("rod.geo")

# %%
mat = FEM.material("body", E=2e5, ν=0)
problem = FEM.Problem([mat], type=:PlaneStress, bandwidth=:RCMK)

# %%
supp1 = FEM.displacementConstraint("left", ux=0)
supp2 = FEM.displacementConstraint("bottom", uy=0)
supp3 = FEM.displacementConstraint("right", ux=0)

# %%
#load = FEM.load("right", fx=1)
#u = FEM.solveDisplacement(problem, [load], [supp1, supp2])
#FEM.showDoFResults(problem, u, :ux, visible=true)

# %%
K = FEM.stiffnessMatrix(problem)

# %%
M = FEM.massMatrix(problem)

# %%
Tmin = FEM.smallestPeriodTime(K, M)

# %%
u0 = FEM.initialDisplacement(problem, "body", ux=0, uy=0);

# %%
v0 = FEM.initialVelocity(problem, "body", vx=1000)
FEM.initialVelocity!(problem, "right", v0, vx=0)

# %%
ωₘₐₓ = 2π / Tmin
C = FEM.dampingMatrix(K, M, ωₘₐₓ, ξ=0);

# %%
dummyLoad = FEM.load("right", fx=0)
f = FEM.loadVector(problem, [dummyLoad]);

# %%
FEM.applyBoundaryConditions!(problem, K, M, C, f, [supp2, supp3]);

# %%
Δt = Tmin / π
c = √(problem.material[1].E / problem.material[1].ρ);
T = 2l / c;

# %%
u, v, t = FEM.CDM(K, M, C, f, u0, v0, T, Δt * 0.5);

# %%
S = FEM.solveStress(problem, u);

# %%
S = FEM.elementsToNodes(problem, S);

# %%
sx = FEM.showDoFResults(problem, S, :sx, t=t);

# %%
psx = FEM.plotOnPath(problem, "path", sx, points=n + 1, visible=true)
psx2, xy = FEM.plotOnPath(problem, "path", sx, points=(n + 1) * 10, step=length(t) ÷ 4, plot=true);

# %%
using Plots
#plotlyjs()
plot(xy)

# %%
fdof = length(FEM.freeDoFs(problem, [supp1, supp2]))

# %%
Φ = FEM.solveModalAnalysis(problem, constraints=[supp1, supp2], n=fdof)
f = Φ.f

# %%
q = Φ.ϕ' * u

# %%
plot(Φ.f, abs.(q[:, size(q, 2)÷4]))

# %%
S = FEM.solveStress(problem, u);

# %%
S = FEM.elementsToNodes(problem, S);

# %%
sx = FEM.showDoFResults(problem, S, :sx, t=t);

# %%
psx = FEM.plotOnPath(problem, "path", sx, points=n + 1, visible=true)
psx2, xy = FEM.plotOnPath(problem, "path", sx, points=(n + 1) * 10, step=length(t) ÷ 4, plot=true);

# %%
using Plots
#plotlyjs()
plot(xy)

# %%
gmsh.fltk.run()

# %%
gmsh.finalize()
