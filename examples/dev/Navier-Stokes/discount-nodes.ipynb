# %%
import gmsh

def check(filename):
    gmsh.initialize()
    gmsh.open(filename)

    nodeTags, _, _ = gmsh.model.mesh.getNodes()

    n = len(nodeTags)

    print(filename)
    print("Number of nodes :", n)
    print("Minimum node tag:", min(nodeTags))
    print("Maximum node tag:", max(nodeTags))
    print("Contiguous      :", min(nodeTags) == 1 and max(nodeTags) == n)
    print()

    gmsh.finalize()


check("pipe-cont.geo")
check("pipe-discont.geo")
# Out:
# Info    : Reading 'pipe-cont.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 50%] Meshing curve 3 (Line)
# Info    : [ 70%] Meshing curve 4 (Line)
# Info    : [ 90%] Meshing curve 5 (Circle)
# Info    : Done meshing 1D (Wall 0.00257102s, CPU 0.001608s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.126255s, CPU 0.11823s)
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 1 order 2
# Info    : [ 20%] Meshing curve 2 order 2
# Info    : [ 40%] Meshing curve 3 order 2
# Info    : [ 60%] Meshing curve 4 order 2
# Info    : [ 70%] Meshing curve 5 order 2
# Info    : [ 90%] Meshing surface 1 order 2
# Info    : Surface mesh: worst distortion = 0.985797 (0 elements in ]0, 0.2]); worst gamma = 0.596085
# Info    : Done meshing order 2 (Wall 0.0174543s, CPU 0.017477s)
# Info    : 6179 nodes 3249 elements
# Info    : Done reading 'pipe-cont.geo'
# pipe-cont.geo
# Number of nodes : 6179
# Minimum node tag: 1
# Maximum node tag: 6179
# Contiguous      : True
#
# Info    : Reading 'pipe-discont.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 50%] Meshing curve 3 (Line)
# Info    : [ 70%] Meshing curve 4 (Line)
# Info    : [ 90%] Meshing curve 5 (Circle)
# Info    : Done meshing 1D (Wall 0.000808069s, CPU 0.001011s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.156544s, CPU 0.121462s)
# Info    : 1622 nodes 3249 elements
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 1 order 2
# Info    : [ 20%] Meshing curve 2 order 2
# Info    : [ 40%] Meshing curve 3 order 2
# Info    : [ 60%] Meshing curve 4 order 2
# Info    : [ 70%] Meshing curve 5 order 2
# Info    : [ 90%] Meshing surface 1 order 2
# Info    : Surface mesh: worst distortion = 0.985797 (0 elements in ]0, 0.2]); worst gamma = 0.596085
# Info    : Done meshing order 2 (Wall 0.0172534s, CPU 0.01744s)
# Info    : Done reading 'pipe-discont.geo'
# pipe-discont.geo
# Number of nodes : 6179
# Minimum node tag: 1
# Maximum node tag: 6194
# Contiguous      : False
