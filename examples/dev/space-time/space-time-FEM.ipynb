# %% [markdown]
# ## Space–time weak formulation
#
# Consider longitudinal wave propagation in a homogeneous one-dimensional elastic bar. The displacement field is denoted by $u(x,t)$, and the governing equation is
#
# $$
# \rho A \frac{\partial^2 u}{\partial t^2}
# -
#
# EA \frac{\partial^2 u}{\partial x^2}
# =0,
# $$
#
# where $E$ is Young's modulus, $\rho$ is the density, and $A$ is the cross-sectional area.
#
# Instead of discretizing space and time separately, we treat time as an additional coordinate and solve the problem directly over the **space–time domain**
#
# $$
# Q=\Omega\times(0,T).
# $$
#
# Let $v(x,t)$ be an admissible test function. Multiplying the governing equation by $v$ and integrating over the complete space–time domain gives
#
# $$
# \int_Q
# v
# \left(
# \rho A\,u_{,tt}
# -
#
# EA\,u_{,xx}
# \right)
# \,dx\,dt
# =0.
# $$
#
# We now integrate both second-order derivatives by parts. For the temporal term,
#
# $$
# \int_Q
# \rho A\,v\,u_{,tt}
# \,dx\,dt
# =
#
# -\int_Q
# \rho A\,v_{,t}u_{,t}
# \,dx\,dt
# +
# \left[
# \int_\Omega
# \rho A\,v\,u_{,t}
# \,dx
# \right]_{0}^{T}.
# $$
#
# Similarly, integration by parts in the spatial direction gives
#
# $$
# -\int_Q
# EA\,v\,u_{,xx}
# \,dx\,dt
# =
#
# \int_Q
# EA\,v_{,x}u_{,x}
# \,dx\,dt
# -
#
# \int_0^T
# \left[
# EA\,v\,u_{,x}
# \right]_{\partial\Omega}
# dt.
# $$
#
# Therefore, the space–time weak form becomes
#
# $$
# \boxed{
# \int_Q
# \left(
# EA\,v_{,x}u_{,x}
# -
#
# \rho A\,v_{,t}u_{,t}
# \right)
# \,dx\,dt
# +
# \left[
# \int_\Omega
# \rho A\,v\,u_{,t}
# \,dx
# \right]_{0}^{T}
# -
#
# \int_0^T
# \left[
# EA\,v\,u_{,x}
# \right]_{\partial\Omega}
# dt
# =0
# }
# $$
#
# The first integral contains the contribution from the interior of the space–time domain. The remaining terms correspond to the boundaries of this domain: the spatial boundaries $x\in\partial\Omega$, and the temporal boundaries $t=0$ and $t=T$.
#
# For the homogeneous interior problem, the bilinear form is therefore
#
# $$
# a(v,u)
# =
#
# \int_Q
# \left(
# EA\,v_{,x}u_{,x}
# -
# \rho A\,v_{,t}u_{,t}
# \right)
# \,dx\,dt.
# $$
#
# This expression can be written in a form that closely resembles a conventional two-dimensional finite-element problem. Introducing the space–time gradient
#
# $$
# \nabla_{xt}u
# =
#
# \begin{bmatrix}
# u_{,x}\
# u_{,t}
# \end{bmatrix},
# $$
#
# we obtain
#
# $$
# a(v,u)
# =
#
# \int_Q
# (\nabla_{xt}v)^T
# \begin{bmatrix}
# EA & 0\\
# 0 & -\rho A
# \end{bmatrix}
# \nabla_{xt}u
# \,dx\,dt.
# $$
#
# Thus, from the finite-element point of view, the one-dimensional wave equation can be interpreted as a two-dimensional scalar problem in the $(x,t)$ plane, with the time coordinate treated in exactly the same way as an additional spatial coordinate. The important difference from an elliptic diffusion problem is the negative sign associated with the temporal derivative.
#
# It is often convenient to introduce the wave speed
#
# $$
# c=\sqrt{\frac{E}{\rho}}
# $$
#
# and the scaled temporal coordinate
#
# $$
# y=ct.
# $$
#
# Since
#
# $$
# \frac{\partial u}{\partial t}
# =
#
# c\frac{\partial u}{\partial y},
# $$
#
# the interior weak form becomes, apart from a constant factor,
#
# $$
# \boxed{
# a(v,u)
# =
#
# \int_Q
# \left(
# v_{,x}u_{,x}
# -
#
# v_{,y}u_{,y}
# \right)
# \,dx\,dy
# }
# $$
#
# or equivalently
#
# $$
# a(v,u)
# =
#
# \int_Q
# (\nabla v)^T
# \begin{bmatrix}
# 1 & 0\\
# 0 & -1
# \end{bmatrix}
# \nabla u
# \,dQ.
# $$
#
# The scaled coordinates $x$ and $y=ct$ have the same physical dimension. In this coordinate system the characteristics of the wave equation satisfy
#
# $$
# x\pm y=\mathrm{const.},
# $$
#
# and therefore appear as straight lines at $45^\circ$ in the space–time domain.
#
# The initial displacement
#
# $$
# u(x,0)=u_0(x)
# $$
#
# can be imposed as an essential boundary condition along the lower boundary of the space–time domain. The initial velocity
#
# $$
# u_{,t}(x,0)=v_0(x)
# $$
#
# appears naturally through the temporal boundary term resulting from integration by parts.
#
# The complete time history is therefore obtained from a single finite-element problem defined over the space–time domain, rather than from a sequence of conventional time-stepping problems.

# %%
using LowLevelFEM, LinearAlgebra

# %%
structured_rect_mesh(lx=100, ly=0.2, n=10, order=2)

mat = Material("body")
U = Problem([mat], type=:ScalarField, dim=2, field=:u, bandwidth=:Metis);

# %%
E = mat.E
ρ = mat.ρ
A = 4
v0 = ScalarField(U, "bottom", (x, y, z)->0.01x)

D = [E*A 0; 0 -ρ*A]
# Out:
# 2×2 Matrix{Float64}:
#  800000.0   0.0
#       0.0  -3.14e-8

# %%
K = ∫(Grad(U) ⋅ D ⋅ Grad(U))
K[:, :]
# Out:
# 210021×210021 SparseArrays.SparseMatrixCSC{Float64, Int64} with 3240081 stored entries:
# ⎡⠿⣧⣤⠀⠀⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎤
# ⎢⠀⠛⢻⣶⣀⡀⠀⠀⠀⠀⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠠⠀⠀⠸⠿⣧⡄⢀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⢉⣻⣾⡀⠀⠄⠀⠀⠀⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠁⠀⠈⠀⠁⠈⠉⠿⣧⣠⠀⠀⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠚⢻⣶⡀⡄⠀⠀⠀⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⠀⠀⠬⠿⣧⡄⢀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢉⢻⣶⣀⠠⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⡀⠀⠀⢀⠀⡘⣻⣾⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠿⣧⡂⠀⠠⠀⠀⠀⠀⢠⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠈⢿⣷⣰⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠂⠐⠚⢻⣶⡄⡀⠀⠠⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠩⠻⣦⣀⢨⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⠀⠀⠀⡀⡀⣘⣻⣾⡀⠀⠀⠀⠀⠀⠀⠀⠀⢀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠿⣧⡅⠀⠀⠀⠀⠀⠀⠐⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠉⢻⣶⣘⠀⠀⠀⠀⢀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠒⠘⠻⣦⡄⡀⠀⠐⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠩⠿⣧⣀⢰⎥
# ⎣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⢀⠀⠀⢀⢀⠀⢀⣘⣻⣾⎦

# %%
f = ∫(U ⋅ (ρ*A*v0), Γ="bottom");

# %%
bcX = BoundaryCondition("left", u=0);

# %%
u = solveField(K, f, support=[bcX]);

# %%
showDoFResults(u, name="u(x,t)")
# Out:
# 0

# %%
openPostProcessor()
