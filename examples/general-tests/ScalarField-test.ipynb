# %%
using LowLevelFEM
# Out:
# [ Info: Precompiling LowLevelFEM [6171b9fb-adbf-4751-adb9-5faded75de07](cache misses: include_dependency fsize change (1), incompatible header (1))
# [ Info: Precompiling LowLevelFEM [6171b9fb-adbf-4751-adb9-5faded75de07] (cache misses: include_dependency fsize change (2), incompatible header (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up

# %%
structured_rect_mesh()

mat = Material("body")
prob = Problem([mat], type=:ScalarField, dim=2, bandwidth=:RCMK)
# Out:
# Problem("structured_rect", :ScalarField, 2, 1, Material[Material("body", :Hooke, 200000.0, 0.3, 115384.61538461536, 76923.07692307692, 166666.66666666663, 7.85e-9, 45.0, 4.2e8, 1.2e-5, 1.0e-7, 0.1, 1.0)], 1.0, 121, LowLevelFEM.Geometry("", "", 0, 0, nothing, nothing, nothing, nothing), :unknown, :rhs)

# %%
s = ScalarField(prob, "body", (x, y, z)->x)
# Out:
# elementwise ScalarField
# [[0.0; 0.1; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.10000000000000009; 0.0;;], [0.0; 0.10000000000000009; 0.09999999999999992; 0.0;;], [0.0; 0.09999999999999992; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;]  …  [0.9; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.8999999999999999;;], [0.8999999999999999; 1.0; 1.0; 0.9000000000000001;;], [0.9000000000000001; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.8999999999999999;;], [0.8999999999999999; 1.0; 1.0; 0.8999999999999999;;], [0.8999999999999999; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.9;;]]

# %%
s2 = scalarField(prob, "body", (x, y, z)->x)
s2 = nodesToElements(s2)
# Out:
# elementwise ScalarField
# [[0.0; 0.1; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.10000000000000009; 0.0;;], [0.0; 0.10000000000000009; 0.09999999999999992; 0.0;;], [0.0; 0.09999999999999992; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; 0.09999999999999998; 0.0;;]  …  [0.9; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.8999999999999999;;], [0.8999999999999999; 1.0; 1.0; 0.9000000000000001;;], [0.9000000000000001; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.8999999999999999;;], [0.8999999999999999; 1.0; 1.0; 0.8999999999999999;;], [0.8999999999999999; 1.0; 1.0; 0.9;;], [0.9; 1.0; 1.0; 0.9;;]]

# %%
showElementResults(s, visible=true)
showElementResults(s2)
# Out:
# 1

# %%
v = VectorField(prob, "body", [(x, y, z)->x, (x, y, z)->y, (x, y, z)->z])
# Out:
# elementwise VectorField
# [[0.0; 0.0; … ; 0.09999999999999998; 0.0;;], [0.0; 0.09999999999999998; … ; 0.19999999999999996; 0.0;;], [0.0; 0.19999999999999996; … ; 0.29999999999999993; 0.0;;], [0.0; 0.29999999999999993; … ; 0.3999999999999999; 0.0;;], [0.0; 0.3999999999999999; … ; 0.5; 0.0;;], [0.0; 0.5; … ; 0.6; 0.0;;], [0.0; 0.6; … ; 0.7; 0.0;;], [0.0; 0.7; … ; 0.8; 0.0;;], [0.0; 0.8; … ; 0.9; 0.0;;], [0.0; 0.9; … ; 1.0; 0.0;;]  …  [0.9; 0.0; … ; 0.09999999999999998; 0.0;;], [0.9; 0.09999999999999998; … ; 0.19999999999999996; 0.0;;], [0.9; 0.19999999999999996; … ; 0.30000000000000004; 0.0;;], [0.8999999999999999; 0.30000000000000004; … ; 0.4; 0.0;;], [0.9000000000000001; 0.4; … ; 0.5; 0.0;;], [0.9; 0.5; … ; 0.6000000000000001; 0.0;;], [0.9; 0.6000000000000001; … ; 0.7000000000000001; 0.0;;], [0.8999999999999999; 0.7000000000000001; … ; 0.8; 0.0;;], [0.8999999999999999; 0.8; … ; 0.9; 0.0;;], [0.9; 0.9; … ; 1.0; 0.0;;]]

# %%
showElementResults(v)
# Out:
# 2

# %%
openPostProcessor()
# Out:
# XOpenIM() failed
# Fontconfig warning: using without calling FcInit()
